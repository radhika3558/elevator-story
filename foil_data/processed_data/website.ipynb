# %%
import pandas as pd
import requests
from dotenv import load_dotenv
import os

# %%
url = f"https://collector-otp-prod.camsys-apps.com/realtime/gtfsrt/ALL/alerts?type=json&apikey=qeqy84JE7hUKfaI0Lxm2Ttcm6ZA0bYrP"
response = requests.get(url)
data = response.json()
data
# Out:
# {'header': {'gtfs_realtime_version': '2.0',
#   'incrementality': 'FULL_DATASET',
#   'timestamp': 1713067209,
#   'transit_realtime.mercury_feed_header': {'mercury_version': '1.0'}},
#  'entity': [{'id': 'lmm:alert:321450',
#    'alert': {'active_period': [{'start': 1713028443}],
#     'informed_entity': [{'agency_id': 'MTA NYCT',
#       'route_id': 'B15',
#       'transit_realtime.mercury_entity_selector': {'sort_order': 'MTA:B15:24'}},
#      {'agency_id': 'MTA NYCT',
#       'route_id': 'B52',
#       'transit_realtime.mercury_entity_selector': {'sort_order': 'MTA:B52:24'}},
#      {'agency_id': 'MTA NYCT',
#       'route_id': 'Q24',
#       'transit_realtime.mercury_entity_selector': {'sort_order': 'MTA:Q24:24'}},
#      {'agency_id': 'MTA NYCT',
#       'route_id': 'Q58',
#       'transit_realtime.mercury_entity_selector': {'sort_order': 'MTA:Q58:24'}}],
# ...

# %%
data['entity']
# Out:
# [{'id': 'lmm:alert:321450',
#   'alert': {'active_period': [{'start': 1713028443}],
#    'informed_entity': [{'agency_id': 'MTA NYCT',
#      'route_id': 'B15',
#      'transit_realtime.mercury_entity_selector': {'sort_order': 'MTA:B15:24'}},
#     {'agency_id': 'MTA NYCT',
#      'route_id': 'B52',
#      'transit_realtime.mercury_entity_selector': {'sort_order': 'MTA:B52:24'}},
#     {'agency_id': 'MTA NYCT',
#      'route_id': 'Q24',
#      'transit_realtime.mercury_entity_selector': {'sort_order': 'MTA:Q24:24'}},
#     {'agency_id': 'MTA NYCT',
#      'route_id': 'Q58',
#      'transit_realtime.mercury_entity_selector': {'sort_order': 'MTA:Q58:24'}}],
#    'header_text': {'translation': [{'text': 'You may wait longer for these buses:\nB15, B20, B35, B52, Q24, Q58, B63, B68.',
#       'language': 'en'},
#      {'text': '<p>You may wait longer for these buses:</p><p><b>B15</b>, <b>B20</b>, <b>B35</b>, <b>B52</b>, <b>Q24</b>, <b>Q58</b>, <b>B63</b>, <b>B68</b>.</p>',
# ...
