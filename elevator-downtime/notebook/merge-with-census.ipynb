# %% [markdown]
# # Notebook Title

# %% [markdown]
# ## Setup Python and R environment
# you can ignore this section

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')

# %% [markdown]
# ## Load & Clean Data
#
# 👉 Load the data along with the census connectors below (the output of the `connect-to-census.ipynb` notebook) and do any cleanup you'd like to do.

# %%
# %%R
# df <- read_csv('2023_subway_censusgeo.csv')
# Out:
# Rows: 18208 Columns: 40
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (26): Common Name, Equipment Description, Executive Comment, Outage Cod...
# dbl  (10): Outage, Station MRN, Station ID, Complex ID, lat, long, ADA, GEOI...
# dttm  (4): Out of Service Date, Estimated Return to Service Date, Actual Ret...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
df = pd.read_csv('data/2023_subway_censusgeo.csv')

# %%
df.shape
# Out:
# (18208, 40)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Out of Service Date Common Name  Outage  \
# 0  2023-01-01 00:14:00       EL376  791238
# 1  2023-01-01 01:04:00       EL189  791257
# 2  2023-01-01 02:01:00       EL293  791274
# 3  2023-01-01 02:08:00      EL449X  791275
# 4  2023-01-01 05:43:00       EL428  791299
#
#                                Equipment Description Executive Comment  \
# 0         ELE: EL376 - 068 - Bay Pkwy - Outside Area               NaN
# 1   ELE: EL189 - 212 - Kingsbridge Rd - Outside Area               NaN
# 2  ELE: EL293 - 119 - 1 Av - Brooklyn Bound Platform               NaN
# 3  ELE: EL449X - 279 - Sutphin Blvd-Archer Av - Mezz               NaN
# 4     ELE: EL428 - 273 - Queens Plaza - Outside Area               NaN
#
#   Outage Code  Status External Source Note Reason Shown to Public  \
# 0          PM  Closed                  NaN            MAINTENANCE
# 1          AP  Closed                  NaN            PLANNEDWORK
# 2         EUF  Closed  UPS Battery Failure                 REPAIR
# 3         TPE  Closed                  NaN                 REPAIR
# 4         VAN  Closed                  NaN                 REPAIR
#
#   Reason Shown to Public Description Estimated Return to Service Date  \
# 0                        Maintenance              2023-01-01 07:00:00
# 1                       Planned Work              2023-01-01 09:00:00
# 2                             Repair              2023-01-01 11:00:00
# 3                             Repair              2023-01-05 14:00:00
# 4                             Repair              2023-01-01 13:00:00
#
#   Actual Return to Service Date           Reference  \
# 0           2023-01-01 05:30:00                 NaN
# 1           2023-01-01 01:18:00                 NaN
# 2           2023-01-01 04:50:00  ST230101.txt - 192
# 3           2023-01-05 03:06:00                 NaN
# 4           2023-01-01 09:10:00                 NaN
#
#                        Source Service Code         Date Created Status Code  \
# 0                       Phone    EE-MANOUT  2023-01-01 00:14:00          CL
# 1                       Phone    EE-MANOUT  2023-01-01 01:05:00          CL
# 2  External Monitoring System     EE-LNOUT  2023-01-01 02:08:00          CL
# 3                       Phone    EE-MANOUT  2023-01-01 02:09:00          CL
# 4                       Phone    EE-MANOUT  2023-01-01 05:44:00          CL
#
#                                      Outage Comments  Station MRN  Station ID  \
# 0  ***This Elevator is out of service for Mainten...           68          68
# 1  \n\n***This elevator is out of service for Acc...          212         212
# 2                                                NaN          119         119
# 3  ***This elevator is out of service as reported...          279         279
# 4                                                NaN          273         273
#
#    Complex ID GTFS Stop ID Division             Line  \
# 0          68          B21      BMT         West End
# 1         212          D04      IND        Concourse
# 2         119          L06      BMT         Canarsie
# 3         279          G06      IND  Queens - Archer
# 4         273          G21      IND      Queens Blvd
#
#                             Stop Name Borough Daytime Routes Structure  \
# 0                            Bay Pkwy      Bk              D  Elevated
# 1                      Kingsbridge Rd      Bx            B D    Subway
# 2                                1 Av       M              L    Subway
# 3  Sutphin Blvd-Archer Av-JFK Airport       Q          E J Z    Subway
# 4                        Queens Plaza       Q          E M R    Subway
#
#          lat       long     North Direction Label South Direction Label  ADA  \
# 0  40.601875 -73.993728                 Manhattan          Coney Island    1
# 1  40.866978 -73.893509  Bedford Pk Blvd & 205 St             Manhattan    1
# 2  40.730953 -73.981628                      8 Av              Brooklyn    1
# 3  40.700486 -73.807969            Jamaica Center             Manhattan    1
# 4  40.748973 -73.937243    Forest Hills - Jamaica             Manhattan    1
#
#   ADA Notes                  Georeference            GEOID  STATE  COUNTY  \
# 0       NaN  POINT (-73.993728 40.601875)  360470296002002     36      47
# 1       NaN  POINT (-73.893509 40.866978)  360050403021003     36       5
# 2       NaN  POINT (-73.981628 40.730953)  360610034004000     36      61
# 3       NaN  POINT (-73.807969 40.700486)  360810208001000     36      81
# 4       NaN  POINT (-73.937243 40.748973)  360810033011019     36      81
#
#    TRACT  BLOCK
# 0  29600   2002
# 1  40302   1003
# 2   3400   4000
# 3  20800   1000
# 4   3301   1019

# %% [markdown]
# ## 👉 Grab Census Data

# %% [markdown]
# 1. loading the Census API key

# %%
import dotenv

# Load the environment variables
# (loads CENSUS_API_KEY from .env)
dotenv.load_dotenv()
# Out:
# True

# %%
# %%R
#
# require('tidycensus')
#
# # because it an environment variable, we don't have to
# # explicitly pass this string to R, it is readable here
# # in this R cell.
# census_api_key(Sys.getenv("CENSUS_API_KEY"))
# Out:
# Loading required package: tidycensus
# To install your API key for use in future sessions, run this function with `install = TRUE`.

# %% [markdown]
# 2. Decide which Census variables you want
#
#     Use <https://censusreporter.org/> to figure out which tables you want. (if censusreporter is down, check out the code in the cell below)
#
#     -   Scroll to the bottom of the page to see the tables.
#     -   If you already know the table ID, stick that in the "Explore" section to learn more about that table.
#
#     By default this code loads (B01003_001) which we found in censusreporter here: https://censusreporter.org/tables/B01003/
#
#     - find some other variables that you're also interested in
#     - don't forget to pick a geography like "tract", "county" or "block group". here is the list of [all geographies](https://walker-data.com/tidycensus/articles/basic-usage.html#geography-in-tidycensus
#     ).

# %%
# %%R 

# Finding the Census Varaibles for the ACS 5 year survey
# Generally you'd do this in CensusReporter, but since it's down sometimes, here it is using tidycensus's load_variables function

# get every single variable in the ACS5
all_census_vars <- load_variables(2021, "acs5", cache = TRUE) 

filtered_census_vars <- all_census_vars %>% 
    filter(grepl("median income", label, ignore.case = TRUE))   # filter to those containing "median income"
    
# write to CSV so we can view it in python
filtered_census_vars %>% 
    write_csv("filtered_census_vars.csv")

# show the first few rows
filtered_census_vars %>%
    select(-geography) %>% # remove the geography column
    print(n = 20) # print the first 20 rows
# Out:
#   Cell In[22], line 9
#     filtered_census_vars <- all_census_vars %>%
#                                              ^
# SyntaxError: invalid syntax

# %%
# %%R
# # the variable B01003_001E was selectd from the census table
# # for population, which we found in censusreporter here:
# # https://censusreporter.org/tables/B01003/
#
# # in the table below, pick the geography, the variables, and the survey you want to pull from
# # see the possible values here https://walker-data.com/tidycensus/articles/basic-usage.html
#
# # Get variable from ACS
# nyc_census_data <- get_acs(geography = "tract",
#                       state='NY',
#                       county = c("New York", "Kings", "Queens", "Bronx", "Richmond"),
#                       variables = c(
#                         population="B01003_001",
#                         med_earn="B19013_001", # Median household income in the past 12 months
#                         sub_pop='B08301_012', # Population using subway or elevated rail to work
#                         amb_pop='B18105_001' # Population with Ambulatory Difficulty
#                       ),
#                       year = 2021,
#                       survey="acs5",
#                       geometry=T)
# options(width = 1000)
#
# nyc_census_data
# Out:
#   |======================================================================| 100%
# Simple feature collection with 9308 features and 5 fields (with 4 geometries empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25609 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# First 10 features:
#          GEOID                                       NAME   variable estimate   moe                       geometry
# 1  36081014700  Census Tract 147, Queens County, New York population     2863   513 MULTIPOLYGON (((-73.9137 40...
# 2  36081014700  Census Tract 147, Queens County, New York    sub_pop      824   210 MULTIPOLYGON (((-73.9137 40...
# 3  36081014700  Census Tract 147, Queens County, New York    amb_pop     2738   508 MULTIPOLYGON (((-73.9137 40...
# 4  36081014700  Census Tract 147, Queens County, New York   med_earn    71815 18034 MULTIPOLYGON (((-73.9137 40...
# 5  36047058400   Census Tract 584, Kings County, New York population     3655   529 MULTIPOLYGON (((-73.96103 4...
# 6  36047058400   Census Tract 584, Kings County, New York    sub_pop      665   188 MULTIPOLYGON (((-73.96103 4...
# 7  36047058400   Census Tract 584, Kings County, New York    amb_pop     3478   523 MULTIPOLYGON (((-73.96103 4...
# 8  36047058400   Census Tract 584, Kings County, New York   med_earn    67315 10294 MULTIPOLYGON (((-73.96103 4...
# 9  36061006900 Census Tract 69, New York County, New York population     2450   372 MULTIPOLYGON (((-74.02064 4...
# 10 36061006900 Census Tract 69, New York County, New York    sub_pop      496   105 MULTIPOLYGON (((-74.02064 4...
# Getting data from the 2017-2021 5-year ACS
# Downloading feature geometry from the Census website.  To cache shapefiles for use in future sessions, set `options(tigris_use_cache = TRUE)`.
# Using FIPS code '36' for state 'NY'
# Using FIPS code '061' for 'New York County'
# Using FIPS code '047' for 'Kings County'
# Using FIPS code '081' for 'Queens County'
# Using FIPS code '005' for 'Bronx County'
# Using FIPS code '085' for 'Richmond County'

# %% [markdown]
# ## 👉 Merge it with your data
#
# hint...`tidycensus` provides you data in long format you may need to pivot the census data from long to wide format before merging it with your data

# %%
# %%R
#
# # pivot from long to wide
# nyc_census_data <- nyc_census_data %>%
#   pivot_wider(
#     names_from = variable,
#     values_from = c(estimate, moe),
#     names_glue = "{variable}_{.value}"
#   )
# options(width = 1000)
# nyc_census_data
# Out:
# Simple feature collection with 2327 features and 10 fields (with 1 geometry empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25609 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# # A tibble: 2,327 × 11
#    GEOID       NAME                                                                                                                       geometry population_estimate sub_pop_estimate amb_pop_estimate med_earn_estimate population_moe sub_pop_moe amb_pop_moe med_earn_moe
#    <chr>       <chr>                                                                                                            <MULTIPOLYGON [°]>               <dbl>            <dbl>            <dbl>             <dbl>          <dbl>       <dbl>       <dbl>        <dbl>
#  1 36081014700 Census Tract 147, Queens County, New York   (((-73.9137 40.76548, -73.9121 40.76473, -73.9113 40.76435, -73.9105 40.76398, -73.9...                2863              824             2738             71815            513         210         508        18034
#  2 36047058400 Census Tract 584, Kings County, New York    (((-73.96103 40.59616, -73.95978 40.5963, -73.95878 40.59641, -73.95785 40.59651, -7...                3655              665             3478             67315            529         188         523        10294
#  3 36061006900 Census Tract 69, New York County, New York  (((-74.02064 40.73039, -74.02006 40.73276, -74.011 40.73232, -74.01026 40.7324, -74....                2450              496             2306            237500            372         105         335        65948
#  4 36047073000 Census Tract 730, Kings County, New York    (((-73.93345 40.6257, -73.93149 40.62559, -73.93174 40.62793, -73.92786 40.62817, -7...                2676              359             2546            117857            534         251         511        22319
#  5 36047100400 Census Tract 1004, Kings County, New York   (((-73.90735 40.63083, -73.90415 40.63295, -73.90233 40.63132, -73.90051 40.62969, -...                3004              402             2805             76207            473         162         454        13504
#  6 36047055700 Census Tract 557, Kings County, New York    (((-73.96279 40.72256, -73.96264 40.72275, -73.96154 40.72388, -73.96161 40.72495, -...                1834              723             1711            107410            324         133         307        37032
#  7 36005022101 Census Tract 221.01, Bronx County, New York (((-73.92012 40.83759, -73.9197 40.83787, -73.91859 40.83898, -73.91768 40.84022, -7...                4030              589             3765             37200            832         183         809        15878
#  8 36081047000 Census Tract 470, Queens County, New York   (((-73.78059 40.71343, -73.778 40.71405, -73.77712 40.71426, -73.77537 40.71168, -73...                3637              422             3369             50000            673         143         586        36794
#  9 36047050402 Census Tract 504.02, Kings County, New York (((-73.97496 40.6478, -73.9735 40.6476, -73.9714 40.64826, -73.97121 40.64762, -73.9...                1758              622             1673            134602            719         391         716        71643
# 10 36047028501 Census Tract 285.01, Kings County, New York (((-73.94439 40.70043, -73.94193 40.70072, -73.94115 40.70028, -73.9389 40.69904, -7...                 356              181              344             50278            100          60          99        15242
# # ℹ 2,317 more rows
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R
# df
# Out:
# # A tibble: 18,208 × 40
#    `Out of Service Date` `Common Name` Outage `Equipment Description`                                  `Executive Comment` `Outage Code` Status `External Source Note`              `Reason Shown to Public` `Reason Shown to Public Description` `Estimated Return to Service Date` `Actual Return to Service Date` Reference          Source                     `Service Code` `Date Created`      `Status Code` `Outage Comments`                                                                                                                                                                                                                                                                                                                                                     `Station MRN` `Station ID` `Complex ID` `GTFS Stop ID` Division Line  `Stop Name` Borough `Daytime Routes` Structure   lat  long North Direction Labe…¹ South Direction Labe…²   ADA `ADA Notes` Georeference   GEOID STATE COUNTY TRACT BLOCK
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R
#
# # keep the first 11 digits in df$GEOID
# df$GEOID <-  substr(df$GEOID, 1, 11) %>%
#     as.numeric(df$GEOID)
#
# # change df$GEOID to double
# nyc_census_data$GEOID <- as.numeric(nyc_census_data$GEOID)
# df$GEOID <- as.numeric(df$GEOID)
#
# # merge nyc_census_data with df on GEOID
# df_census <- merge(df, nyc_census_data, by = "GEOID")

# %%
# %%R
# write_csv(df_census, "data/2023_subway_censusvar.csv")

# %% [markdown]
# ## Create an agg dataset

# %%
df = pd.read_csv('data/2023_subway_censusvar.csv')

# %%
value_count = df['Common Name'].value_counts()
df['outage_count'] = df['Common Name'].map(value_count)
df.sample(5)
# Out:
#              GEOID   Out of Service Date Common Name  Outage  \
# 2172   36047000501  2023-04-15T19:26:00Z       EL310  833097
# 11352  36061012602  2023-12-20T17:38:00Z       EL267  957993
# 2604   36047001100  2023-06-16T00:20:00Z       EL709  883831
# 11929  36061014500  2023-07-26T00:03:00Z       EL280  899695
# 15484  36061028300  2023-07-17T23:25:00Z       EL178  896395
#
#                                    Equipment Description  \
# 2172                ELE: EL310 - 334 - Clark St - Mezz A
# 11352            ELE: EL267 - 477 - 72 St - Outside Area
# 2604   ELE: EL709 - 025 - Jay St-MetroTech - Island Plat
# 11929  ELE: EL280 - 161 - 59 St-Columbus Circle - Mezz A
# 15484                      ELE: EL178 - 299 - Dyckman St
#
#                                        Executive Comment Outage Code  \
# 2172                                                 NaN         UNI
# 11352  this elevator out of service due to LO/TO trai...          AP
# 2604                                                 NaN          PM
# 11929                                                NaN         CLN
# 15484                                                NaN          PM
#
#           Status External Source Note Reason Shown to Public  \
# 2172   Cancelled        No Comm/Power           UNDERINVESTG
# 11352     Closed                  NaN            PLANNEDWORK
# 2604      Closed                  NaN            MAINTENANCE
# 11929     Closed                  NaN               CLEANING
# 15484     Closed                  NaN            MAINTENANCE
#
#       Reason Shown to Public Description Estimated Return to Service Date  \
# 2172                 Under Investigation             2023-04-16T04:00:00Z
# 11352                       Planned Work             2023-12-20T23:00:00Z
# 2604                         Maintenance             2023-06-16T07:22:00Z
# 11929                           Cleaning             2023-07-26T07:00:00Z
# 15484                        Maintenance             2023-07-18T05:25:00Z
#
#       Actual Return to Service Date            Reference  \
# 2172                            NaN  ST230415.txt - 1764
# 11352          2023-12-20T17:55:00Z                  NaN
# 2604           2023-06-16T05:30:00Z                  NaN
# 11929          2023-07-26T04:30:00Z                  NaN
# 15484          2023-07-18T05:00:00Z                  NaN
#
#                            Source Service Code          Date Created  \
# 2172   External Monitoring System     EE-LNOUT  2023-04-15T19:34:00Z
# 11352                       Phone    EE-MANOUT  2023-12-20T17:39:00Z
# 2604                        Phone    EE-MANOUT  2023-06-16T00:22:00Z
# 11929                       Phone    EE-MANOUT  2023-07-26T00:04:00Z
# 15484                       Phone    EE-MANOUT  2023-07-17T23:27:00Z
#
#       Status Code                                    Outage Comments  \
# 2172            C  As per SA Anderson (R600, #013122) EL310 is In...
# 11352          CL  \n\n\nE&EH Gurung taking machine out for LO/TO...
# 2604           CL  ***The elevator is out of service due to Reven...
# 11929          CL  ***This Elevator is out of service for Cleanin...
# 15484          CL  **Elevator OOS for Monthly PM ***\n\n\nWO  693...
#
#        Station MRN  Station ID  Complex ID GTFS Stop ID Division  \
# 2172           334         334         334          231      IRT
# 11352          477         477         477          Q03      IND
# 2604            25          25         636          R29      BMT
# 11929          161         161         614          A24      IND
# 15484          299         299         299          109      IRT
#
#                      Line              Stop Name Borough Daytime Routes  \
# 2172             Clark St               Clark St      Bk            2 3
# 11352           Second Av                  72 St       M              Q
# 2604             Broadway       Jay St-MetroTech      Bk              R
# 11929  8th Av - Fulton St  59 St-Columbus Circle       M        A B C D
# 15484      Broadway - 7Av             Dyckman St       M              1
#
#       Structure        lat       long North Direction Label  \
# 2172     Subway  40.697466 -73.993086             Manhattan
# 11352    Subway  40.768799 -73.958424                Uptown
# 2604     Subway  40.692180 -73.985942             Manhattan
# 11929    Subway  40.768296 -73.981736    Uptown & The Bronx
# 15484  Elevated  40.860531 -73.925536    Uptown & The Bronx
#
#       South Direction Label  ADA ADA Notes                  Georeference  \
# 2172    Flatbush - New Lots    0       NaN  POINT (-73.993086 40.697466)
# 11352   Downtown & Brooklyn    1       NaN  POINT (-73.958424 40.768799)
# 2604      Bay Ridge - 95 St    1       NaN   POINT (-73.985942 40.69218)
# 11929   Downtown & Brooklyn    1       NaN  POINT (-73.981736 40.768296)
# 15484              Downtown    1       NaN  POINT (-73.925536 40.860531)
#
#        STATE  COUNTY  TRACT  BLOCK  \
# 2172      36      47    501   1001
# 11352     36      61  12602   2000
# 2604      36      47   1100   1011
# 11929     36      61  14500   4002
# 15484     36      61  28300   2000
#
#                                                  NAME  \
# 2172        Census Tract 5.01, Kings County, New York
# 11352  Census Tract 126.02, New York County, New York
# 2604          Census Tract 11, Kings County, New York
# 11929     Census Tract 145, New York County, New York
# 15484     Census Tract 283, New York County, New York
#
#                                                 geometry  population_estimate  \
# 2172   list(list(c(-73.996197, -73.995855, -73.995547...                 4604
# 11352  list(list(c(-73.961559, -73.961102, -73.960602...                 4847
# 2604   list(list(c(-73.990447, -73.990663, -73.990746...                 1508
# 11929  list(list(c(-73.987615, -73.987146, -73.986695...                 6401
# 15484  list(list(c(-73.931818, -73.931313, -73.92842,...                 8463
#
#        sub_pop_estimate  amb_pop_estimate  med_earn_estimate  population_moe  \
# 2172               1094              4385           141354.0             493
# 11352               808              4616           177882.0            1092
# 2604                670              1414           154167.0             254
# 11929              1240              5873           184231.0             817
# 15484              2156              8295            64394.0            1556
#
#        sub_pop_moe  amb_pop_moe  med_earn_moe  outage_count
# 2172           192          497       30955.0            94
# 11352          291          945       39112.0            43
# 2604           111          197       34801.0            51
# 11929          315          735       25765.0            59
# 15484          438         1550        9896.0            45

# %%
df_agg = df.drop_duplicates(subset=['Common Name'])
# drop column `Outage`, `Out of Service Date`, `Executive Comment,	Outage Code	Status,	External Source Note,	Reason Shown to Public,	Reason Shown to Public Description,	`Estimated Return to Service Date`
df_agg = df_agg.drop(columns=['Outage', 
                              'Out of Service Date', 
                              'Executive Comment', 
                              'Outage Code', 
                              'Status', 
                              'External Source Note', 
                              'Reason Shown to Public', 
                              'Reason Shown to Public Description', 
                              'Estimated Return to Service Date',
                              'Actual Return to Service Date',
                              'Reference',
                              'Source',
                              'Service Code',
                              'Date Created',
                              'Status Code',
                            'Outage Comments'])
df_agg.shape
# Out:
# (362, 35)

# %%
df_agg
# Out:
#              GEOID Common Name  \
# 0      36005006500       EL130
# 6      36005006500       EL129
# 135    36005008300       EL516
# 136    36005008300       EL515
# 153    36005011900       EL196
# ...            ...         ...
# 18024  36081093800       EL499
# 18038  36081100803       EL498
# 18039  36081100803       EL497
# 18181  36085013400       EL788
# 18182  36085013400       EL787
#
#                                    Equipment Description  Station MRN  \
# 0                         ELE: EL130 - 434 - 3 Av-149 St          434
# 6                         ELE: EL129 - 434 - 3 Av-149 St          434
# 135                        ELE: EL516 - 373 - E 149TH St          373
# 136                        ELE: EL515 - 373 - E 149TH St          373
# 153                    ELE: EL196 - 371 - Hunts Point Av          371
# ...                                                  ...          ...
# 18024      ELE: EL499 - 203 - Rockaway Park-Beach 116 St          203
# 18038  ELE: EL498 - 209 - Far Rockaway-Mott Av - Isla...          209
# 18039  ELE: EL497 - 209 - Far Rockaway-Mott Av - Isla...          209
# 18181                        ELE: EL788 - 510 - NEW DORP          510
# 18182                        ELE: EL787 - 510 - NEW DORP          510
#
#        Station ID  Complex ID GTFS Stop ID Division                     Line  \
# 0             434         434          221      IRT  Lenox - White Plains Rd
# 6             434         434          221      IRT  Lenox - White Plains Rd
# 135           373         373          615      IRT                   Pelham
# 136           373         373          615      IRT                   Pelham
# 153           371         371          613      IRT                   Pelham
# ...           ...         ...          ...      ...                      ...
# 18024         203         203          H15      IND                 Rockaway
# 18038         209         209          H11      IND                 Rockaway
# 18039         209         209          H11      IND                 Rockaway
# 18181         510         510          S22      SIR            Staten Island
# 18182         510         510          S22      SIR            Staten Island
#
#                         Stop Name Borough Daytime Routes Structure        lat  \
# 0                     3 Av-149 St      Bx            2 5    Subway  40.816109
# 6                     3 Av-149 St      Bx            2 5    Subway  40.816109
# 135                      E 149 St      Bx              6    Subway  40.812118
# 136                      E 149 St      Bx              6    Subway  40.812118
# 153                Hunts Point Av      Bx              6    Subway  40.820948
# ...                           ...     ...            ...       ...        ...
# 18024  Rockaway Park-Beach 116 St       Q            A S  At Grade  40.580903
# 18038        Far Rockaway-Mott Av       Q              A   Viaduct  40.603995
# 18039        Far Rockaway-Mott Av       Q              A   Viaduct  40.603995
# 18181                    New Dorp      SI            SIR  Open Cut  40.573480
# 18182                    New Dorp      SI            SIR  Open Cut  40.573480
#
#             long    North Direction Label South Direction Label  ADA  \
# 0     -73.917757  Wakefield - Eastchester             Manhattan    1
# 6     -73.917757  Wakefield - Eastchester             Manhattan    1
# 135   -73.904098          Pelham Bay Park             Manhattan    1
# 136   -73.904098          Pelham Bay Park             Manhattan    1
# 153   -73.890549          Pelham Bay Park             Manhattan    1
# ...          ...                      ...                   ...  ...
# 18024 -73.835592                Manhattan                   NaN    1
# 18038 -73.755405                Manhattan                   NaN    1
# 18039 -73.755405                Manhattan                   NaN    1
# 18181 -74.117210                St George           Tottenville    1
# 18182 -74.117210                St George           Tottenville    1
#
#       ADA Notes                  Georeference  STATE  COUNTY   TRACT  BLOCK  \
# 0           NaN  POINT (-73.917757 40.816109)     36       5    6500   1000
# 6           NaN  POINT (-73.917757 40.816109)     36       5    6500   1000
# 135         NaN  POINT (-73.904098 40.812118)     36       5    8300   5000
# 136         NaN  POINT (-73.904098 40.812118)     36       5    8300   5000
# 153         NaN  POINT (-73.890549 40.820948)     36       5   11900   1002
# ...         ...                           ...    ...     ...     ...    ...
# 18024       NaN  POINT (-73.835592 40.580903)     36      81   93800   3003
# 18038       NaN  POINT (-73.755405 40.603995)     36      81  100803   1000
# 18039       NaN  POINT (-73.755405 40.603995)     36      81  100803   1000
# 18181       NaN    POINT (-74.11721 40.57348)     36      85   13400   1005
# 18182       NaN    POINT (-74.11721 40.57348)     36      85   13400   1005
#
#                                                 NAME  \
# 0            Census Tract 65, Bronx County, New York
# 6            Census Tract 65, Bronx County, New York
# 135          Census Tract 83, Bronx County, New York
# 136          Census Tract 83, Bronx County, New York
# 153         Census Tract 119, Bronx County, New York
# ...                                              ...
# 18024      Census Tract 938, Queens County, New York
# 18038  Census Tract 1008.03, Queens County, New York
# 18039  Census Tract 1008.03, Queens County, New York
# 18181    Census Tract 134, Richmond County, New York
# 18182    Census Tract 134, Richmond County, New York
#
#                                                 geometry  population_estimate  \
# 0      list(list(c(-73.925185, -73.924025, -73.922652...                 5681
# 6      list(list(c(-73.925185, -73.924025, -73.922652...                 5681
# 135    list(list(c(-73.904183, -73.903804, -73.90347,...                 6121
# 136    list(list(c(-73.904183, -73.903804, -73.90347,...                 6121
# 153    list(list(c(-73.892005, -73.89139, -73.890586,...                 6193
# ...                                                  ...                  ...
# 18024  list(list(c(-73.840704, -73.833507, -73.82733,...                 5289
# 18038  list(list(c(-73.763868, -73.761639, -73.760598...                 4081
# 18039  list(list(c(-73.763868, -73.761639, -73.760598...                 4081
# 18181  list(list(c(-74.123427, -74.122169, -74.121286...                 4225
# 18182  list(list(c(-74.123427, -74.122169, -74.121286...                 4225
#
#        sub_pop_estimate  amb_pop_estimate  med_earn_estimate  population_moe  \
# 0                  1004              4827            21962.0             908
# 6                  1004              4827            21962.0             908
# 135                 864              5751            42386.0             913
# 136                 864              5751            42386.0             913
# 153                1312              5690            32007.0            1055
# ...                 ...               ...                ...             ...
# 18024               368              4352            60917.0             744
# 18038               562              3899            44146.0             792
# 18039               562              3899            44146.0             792
# 18181                76              4113            79412.0             704
# 18182                76              4113            79412.0             704
#
#        sub_pop_moe  amb_pop_moe  med_earn_moe  outage_count
# 0              270          587        5408.0            94
# 6              270          587        5408.0            41
# 135            285          847        4187.0            10
# 136            285          847        4187.0             8
# 153            466          969        6069.0            76
# ...            ...          ...           ...           ...
# 18024          181          607       15288.0            14
# 18038          210          748       20424.0            43
# 18039          210          748       20424.0           100
# 18181           48          692       28002.0            12
# 18182           48          692       28002.0            15
#
# [362 rows x 35 columns]

# %%
df_agg.to_csv('data/2023_subway_censusvar_agg.csv', index=False)
