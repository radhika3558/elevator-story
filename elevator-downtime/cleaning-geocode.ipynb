# %% [markdown]
# # Cleaning & Geolocating

# %% [markdown]
# ## Setup Python and R environment
# you can ignore this section

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse

# %% [markdown]
# ## 👉 download your data
#
# You can write code here to download your dataset. Or if you already have it, just leave the URL in the comments and just load it into a pandas or R (or both) dataframe.

# %%
df = pd.read_excel('raw_data/2023.xlsx')
df.to_csv('raw_data/2023.csv', index=False)
pd.set_option('display.max_colwidth', None)
df.sample(10)
# Out:
#       Out of Service Date Common Name  Outage  \
# 48293 2023-12-16 13:33:00       ES260  956202
# 14765 2023-04-20 03:33:00      EL729X  834746
# 36577 2023-09-20 07:00:00       ES624  922050
# 22166 2023-06-10 21:25:00       ES328  881304
# 58    2023-01-01 16:48:00       EL104  791369
# 23592 2023-06-20 08:13:00       EL235  885302
# 10956 2023-03-23 11:04:00       ES214  823792
# 17584 2023-05-09 19:40:00       EL222  851905
# 9850  2023-03-17 06:45:00       EL144  820735
# 2069  2023-01-16 18:48:00       ES423  797168
#
#                                                  Equipment Description  \
# 48293                          ESC: ES260 - 475 - 96 St - Outside Area
# 14765              ELE: EL729X - 412 - Fulton St - Brooklyn Bound Plat
# 36577                   ESC: ES624 - 471 - 34 St-Hudson Yards - Mezz A
# 22166      ESC: ES328 - 233 - Delancey St-Essex St - Queens Bound Plat
# 58                                           ELE: EL104 - 300 - 191 St
# 23592  ELE: EL235 - 225 -47-50 Sts-Rockefeller Ctr - Queens Bound Plat
# 10956             ESC: ES214 - 400 - 59 St - Brooklyn Bound Local Plat
# 17584                   ELE: EL222 - 166 - 14 St - Brooklyn Bound Plat
# 9850                                         ELE: EL144 - 153 - 125 St
# 2069       ESC: ES423 - 221 - 21 St-Queensbridge - Brooklyn Bound Plat
#
#                                                                   Executive Comment  \
# 48293  This escalator is out of service for Liftnet Event : Safety Brake Release #3
# 14765                                                                           NaN
# 36577                   This escalator is out of service for preventive maintenance
# 22166                                                                           NaN
# 58                                                                              NaN
# 23592                                                                           NaN
# 10956                                                                           NaN
# 17584                                                                           NaN
# 9850                                                                            NaN
# 2069                                                                            NaN
#
#       Outage Code     Status                      External Source Note  \
# 48293         BRP     Closed                   Safety Brake Release #3
# 14765         TPE     Closed                                       NaN
# 36577          PM     Closed                                       NaN
# 22166         VAN     Closed                                     Ready
# 58            BRP     Closed  Door Opening/ R. Door Open Limit failure
# 23592          FR  Cancelled                  DOWN SLOWDOWN LIMIT OPEN
# 10956         MRP     Closed                                       NaN
# 17584          PM     Closed                                       NaN
# 9850          POW     Closed                               Power Fault
# 2069          VAN     Closed                                     Ready
#
#       Reason Shown to Public Reason Shown to Public Description  \
# 48293                 REPAIR                             Repair
# 14765                 REPAIR                             Repair
# 36577            MAINTENANCE                        Maintenance
# 22166           UNDERINVESTG                Under Investigation
# 58                    REPAIR                             Repair
# 23592           UNDERINVESTG                Under Investigation
# 10956            PLANNEDWORK                       Planned Work
# 17584            MAINTENANCE                        Maintenance
# 9850            UNDERINVESTG                Under Investigation
# 2069            UNDERINVESTG                Under Investigation
#
#       Estimated Return to Service Date Actual Return to Service Date  \
# 48293              2023-12-16 22:00:00           2023-12-16 16:55:00
# 14765              2023-04-22 12:00:00           2023-04-20 09:39:00
# 36577              2023-09-20 15:00:00           2023-09-20 12:40:00
# 22166              2023-06-11 06:00:00           2023-06-11 01:00:00
# 58                 2023-01-02 01:00:00           2023-01-02 00:15:00
# 23592              2023-06-20 17:00:00                           NaT
# 10956              2023-03-23 16:00:00           2023-03-23 12:55:00
# 17584              2023-05-10 07:00:00           2023-05-10 04:30:00
# 9850               2023-03-17 15:00:00           2023-03-17 11:00:00
# 2069               2023-01-17 03:00:00           2023-01-16 19:45:00
#
#                  Reference                      Source Service Code  \
# 48293  ST231216.txt - 1592  External Monitoring System     EE-LNOUT
# 14765                  NaN                       Phone    EE-MANOUT
# 36577                  NaN                       Phone    EE-MANOUT
# 22166  ST230610.txt - 2804  External Monitoring System     EE-LNOUT
# 58     ST230101.txt - 1297  External Monitoring System     EE-LNOUT
# 23592  ST230620.txt - 1180  External Monitoring System     EE-LNOUT
# 10956                  NaN                       Phone    EE-MANOUT
# 17584                  NaN                       Phone    EE-MANOUT
# 9850    ST230317.txt - 707  External Monitoring System     EE-LNOUT
# 2069   ST230116.txt - 1899  External Monitoring System     EE-LNOUT
#
#              Date Created Status Code  \
# 48293 2023-12-16 13:35:00          CL
# 14765 2023-04-20 03:33:00          CL
# 36577 2023-09-20 07:14:00          CL
# 22166 2023-06-10 21:38:00          CL
# 58    2023-01-01 16:54:00          CL
# 23592 2023-06-20 08:23:00           C
# 10956 2023-03-23 11:04:00          CL
# 17584 2023-05-09 19:41:00          CL
# 9850  2023-03-17 06:55:00          CL
# 2069  2023-01-16 18:57:00          CL
#
#                                                                                                                                                                                                                                                                                                            Outage Comments
# 48293                                                                                                                                                                                                                                                                                                                  NaN
# 14765  **This elevator is out of service as reported by S/S Dasgupta***\n**This machine is out of service for required repairs. NYC Transit is not responsible for the maintenance or repair of this unit** @ 09:19 Notified Supt. Bertolino to check elevator status.  As per E&EM Rapoport this elevator is in service.
# 36577                                                                                                                                        E&EM Pharous & Schoendorf and E&EH Ahmed arrive at 0530. Here for schedule "D" PM. Machine out of service at 0700. WO#7750996 E&EH Ahmed RTS after completing PM @1240 hrs.
# 22166                                                                                                                                                                                                                                                                                                                  NaN
# 58                                                                                                                                                                                                                                                                                                                     NaN
# 23592                                                                                                                                                                                                                                                                    As per Liftnet Galaxy Client machine is running.
# 10956                                                                                                                                                                                                                                                                                                                  NaN
# 17584             *** This elevator is out of service due to Elevator Quarterly Maintenance*** WO#6365537\nE&EM George and E&EH Dowers arrived for Quarterly PM. taking machine out of service at 19:40  5/10/23 @ 0430   (Rosario)  E&EM George and E&EH Dowers     reports completed\n quarterly maintenance.   RTS\n\n
# 9850                                                                                                                                                                                                                                                                                                                   NaN
# 2069                                                                                                                                                                                                                                                                                                                   NaN

# %%
# %%R
# df <- read_csv('raw_data/2023.csv')
# Out:
# Rows: 50296 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (13): Common Name, Equipment Description, Executive Comment, Outage Cod...
# dbl   (1): Outage
# dttm  (4): Out of Service Date, Estimated Return to Service Date, Actual Ret...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# ## 👉 convert addresses --> lat/long
#
# See the [census-examples](https://github.com/data4news/census-examples) repository for examples. If you need help, try asking in the class slack channel. Chances are someone in the class is struggling with the same problem as you are so we might as well all learn together in the same slack channel!

# %%
# filter down to elevators only
df_ele = df[df['Equipment Description'].str.startswith('ELE')]
df_ele.sample(10)
# Out:
#       Out of Service Date Common Name  Outage  \
# 12268 2023-04-02 06:49:00       EL204  827928
# 8112  2023-03-04 00:55:00       EL306  815864
# 21035 2023-06-02 01:38:00       EL133  878378
# 40379 2023-10-19 00:20:00       EL498  933801
# 5242  2023-02-09 13:15:00       EL135  807345
# 40738 2023-10-22 03:30:00       EL182  934924
# 27518 2023-07-17 14:01:00       EL328  896284
# 13935 2023-04-14 07:17:00       EL458  832497
# 6383  2023-02-18 00:26:00       EL435  810574
# 16406 2023-05-01 12:10:00       EL129  839134
#
#                                                     Equipment Description  \
# 12268               ELE: EL204 - 402 - Grand Central-42 St - Outside Area
# 8112   ELE: EL306 - 338 - Atlantic Av-Barclays Ctr - Manhattan Bound Plat
# 21035                            ELE: EL133 - 219 - 161 St-Yankee Stadium
# 40379               ELE: EL498 - 209 - Far Rockaway-Mott Av - Island Plat
# 5242                             ELE: EL135 - 219 - 161 St-Yankee Stadium
# 40738                                      ELE: EL182 - 421 - Gun Hill Rd
# 27518                ELE: EL328 - 230 - B'way-Lafayette St - Outside Area
# 13935                 ELE: EL458 - 965 - FREIGHT ELEVATOR AT WOODSIDE EMD
# 6383        ELE: EL435 - 259 - Kew Gardens-Union Tpke - Queens Bound Plat
# 16406                                      ELE: EL129 - 434 - 3 Av-149 St
#
#                                                 Executive Comment Outage Code  \
# 12268                                                         NaN          FR
# 8112                                                          NaN          PM
# 21035                                                         NaN         MRP
# 40379  This Elevator is out of service for Quarterly Maintenance.          PM
# 5242                                                          NaN         APC
# 40738          This elevator is out of service for Glass Cleaning          PM
# 27518                                                         NaN         BRP
# 13935                                                         NaN         MRP
# 6383                                                          NaN         BRP
# 16406                                                         NaN         MRP
#
#           Status External Source Note Reason Shown to Public  \
# 12268  Cancelled   24V +A Fuse (FU12)           UNDERINVESTG
# 8112      Closed                  NaN            MAINTENANCE
# 21035     Closed                  NaN            PLANNEDWORK
# 40379     Closed                  NaN            MAINTENANCE
# 5242      Closed                  NaN            PLANNEDWORK
# 40738     Closed                  NaN            MAINTENANCE
# 27518     Closed         Fire Phase 1                 REPAIR
# 13935     Closed                  NaN            PLANNEDWORK
# 6383      Closed         Fire Phase 1           UNDERINVESTG
# 16406     Closed                  NaN            PLANNEDWORK
#
#       Reason Shown to Public Description Estimated Return to Service Date  \
# 12268                Under Investigation              2023-04-02 15:00:00
# 8112                         Maintenance              2023-03-04 09:00:00
# 21035                       Planned Work              2023-06-02 09:00:00
# 40379                        Maintenance              2023-10-19 09:00:00
# 5242                        Planned Work              2023-02-09 22:00:00
# 40738                        Maintenance              2023-10-22 11:00:00
# 27518                             Repair              2023-07-17 23:00:00
# 13935                       Planned Work              2023-04-14 16:00:00
# 6383                 Under Investigation              2023-02-18 09:00:00
# 16406                       Planned Work              2023-05-01 20:00:00
#
#       Actual Return to Service Date            Reference  \
# 12268                           NaT   ST230402.txt - 419
# 8112            2023-03-04 05:30:00                  NaN
# 21035           2023-06-02 02:55:00                  NaN
# 40379           2023-10-19 05:00:00                  NaN
# 5242            2023-02-09 14:20:00                  NaN
# 40738           2023-10-22 04:30:00                  NaN
# 27518           2023-07-17 17:20:00  ST230717.txt - 2115
# 13935           2023-04-14 14:30:00                  NaN
# 6383            2023-02-18 01:56:00    ST230218.txt - 86
# 16406           2023-05-01 12:30:00                  NaN
#
#                            Source Service Code        Date Created  \
# 12268  External Monitoring System     EE-LNOUT 2023-04-02 06:58:00
# 8112                        Phone    EE-MANOUT 2023-03-04 00:56:00
# 21035                       Phone    EE-MANOUT 2023-06-02 01:38:00
# 40379                       Phone    EE-MANOUT 2023-10-19 00:23:00
# 5242                        Phone    EE-MANOUT 2023-02-09 13:17:00
# 40738                       Phone    EE-MANOUT 2023-10-22 03:33:00
# 27518  External Monitoring System     EE-LNOUT 2023-07-17 14:16:00
# 13935                       Phone    EE-MANOUT 2023-04-14 07:19:00
# 6383   External Monitoring System     EE-LNOUT 2023-02-18 00:37:00
# 16406                       Phone    EE-MANOUT 2023-05-01 12:11:00
#
#       Status Code  \
# 12268           C
# 8112           CL
# 21035          CL
# 40379          CL
# 5242           CL
# 40738          CL
# 27518          CL
# 13935          CL
# 6383           CL
# 16406          CL
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Outage Comments
# 12268                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Both Liftnets are showing conflicting information. Spoke to MS1 Sookdhan. Spoke to S/A Jones #44620 elevator is working as design.
# 8112                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ***This elevator is out of service for Monthly PM***\nWO5898910   EAM OUT815864\n3/04/23 0055hrs {Jackson,R}E&EM Figueroa, E&EH Lattanzio, and E&EH Stewart taking unit OOS for Monthly PM Maintenance completed. Machine BIS @05:30 hrs
# 21035                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 40379                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            E&EM Grant and E&EH Taiwo arrived at El498 at 0010 hours for quarterly PM. Out of service 0015 hours. WO#8021129 PM Complete RTS @0500HRS
# 5242                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ***This elevator is out of service for A&P for CBA Contractor to perform the survey***\n\n\n\nE&EM Lazariev taking unit OOS to provide A&P for CBA Contractor to perform the survey. WO#5683516 E&EM Garcia: Completed survey for contractors tested machine run RTS at 1420H
# 40738                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       E&EM Louis and E&EH Titus arrived at el182 for glass cleaning. WO8264718 Completed glass cleaning. Cleaned in car glass panels. Test run and BIS at 0430 hours
# 27518                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 13935  ***This elevator is out of service for top landing hoist way door hanger rollers and gibs replacement***\n\n\n\nRichmond tech. Soto/Moran taking elevator OOS to replace top landing hoist way door hanger rollers and gibs. WO#6214647 Richmond tech. Soto/Moran: Cleaned out Removed old hoist-way door hanger rollers at top landing \nWe are in the process of installing new hanger rollers at hoist-way door top landing \n\n Richmond tech. Soto/Moran: Cleaned out Removed old hoist-way door hanger rollers top landings We are in the process to install new hanger rollers hoist-way door top landing.\n\n Richmond tech. Moran email:  Finished installed hanger rollers hoistway door top landing. Adjusted door for proper clearance. RTS @14:30 \n\n
# 6383                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# 16406                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN

# %%
# create column `station MRN` to merge with `Station ID` to geolocate
df_ele['Station MRN'] = df_ele['Equipment Description'].str.extract(r'ELE: EL\d{2,3}\w? - (\d{2,3})\s-')

# %%
# check what the are the missing station MRN
# missing values are all elevators that are either located in New Utrecht Av (MRN: 73) or Dyckman St Quarters(MRN: TBD)

print(df_ele[df_ele['Station MRN'].isna()].shape)
df_ele[df_ele['Station MRN'].isna()].to_csv('missing_data/2023_missing_station_mrn.csv', index=False)
df_ele[df_ele['Station MRN'].isna()].sample(10)
# Out:
# (147, 19)
#       Out of Service Date Common Name  Outage  \
# 31990 2023-08-18 00:13:00       EL740  908770
# 7071  2023-02-23 13:19:00       EL741  812858
# 44792 2023-11-21 00:10:00       EL741  946059
# 20984 2023-06-01 17:09:00       EL740  878254
# 41266 2023-10-26 07:35:00       EL156  936422
# 34352 2023-09-05 12:10:00       EL741  915449
# 35355 2023-09-12 12:56:00       EL739  918347
# 29807 2023-08-02 07:55:00       EL739  902302
# 22530 2023-06-13 10:15:00       EL156  882314
# 37326 2023-09-26 08:45:00       EL740  924804
#
#                                        Equipment Description  \
# 31990          ELE: EL740 - 73  - New Utrecht - Location TBD
# 7071           ELE: EL741 - 73  - New Utrecht - Location TBD
# 44792          ELE: EL741 - 73  - New Utrecht - Location TBD
# 20984          ELE: EL740 - 73  - New Utrecht - Location TBD
# 41266  ELE: EL156 - TBD - Dyckman St Quarters - Location TBD
# 34352          ELE: EL741 - 73  - New Utrecht - Location TBD
# 35355          ELE: EL739 - 73  - New Utrecht - Location TBD
# 29807          ELE: EL739 - 73  - New Utrecht - Location TBD
# 22530  ELE: EL156 - TBD - Dyckman St Quarters - Location TBD
# 37326          ELE: EL740 - 73  - New Utrecht - Location TBD
#
#                                                                           Executive Comment  \
# 31990                                                                                   NaN
# 7071                                                                                    NaN
# 44792       ****This Elevator is Out for Monthly Preventative Maintenance**** \n\nWO8275719
# 20984                                                                                   NaN
# 41266                      This elevator is out of service to inspect guide shoes and rails
# 34352            This elevator is out of service for Verification of the As-built drawings.
# 35355  S/A Cheng #147466 reported the Street landing hall-call button is not taking calls.
# 29807                                                                                   NaN
# 22530                                                                                   NaN
# 37326                      E&E personnel removed this unit from service to correct defects.
#
#       Outage Code  Status                     External Source Note  \
# 31990         INS  Closed                                      NaN
# 7071          BRP  Closed  Front Gate Switch Bypass Switch Failure
# 44792          PM  Closed                                      NaN
# 20984         BRP  Closed         Positioning Signal HT1/HT2 Fault
# 41266         MRP  Closed                                      NaN
# 34352         APC  Closed                                      NaN
# 35355         BRP  Closed                                      NaN
# 29807          PM  Closed                                      NaN
# 22530         INS  Closed                                      NaN
# 37326         MRP  Closed                                      NaN
#
#       Reason Shown to Public Reason Shown to Public Description  \
# 31990             INSPECTION                         Inspection
# 7071            UNDERINVESTG                Under Investigation
# 44792            MAINTENANCE                        Maintenance
# 20984           UNDERINVESTG                Under Investigation
# 41266            PLANNEDWORK                       Planned Work
# 34352            PLANNEDWORK                       Planned Work
# 35355                 REPAIR                             Repair
# 29807            MAINTENANCE                        Maintenance
# 22530             INSPECTION                         Inspection
# 37326            PLANNEDWORK                       Planned Work
#
#       Estimated Return to Service Date Actual Return to Service Date  \
# 31990              2023-08-18 08:00:00           2023-08-18 04:15:00
# 7071               2023-02-23 22:00:00           2023-02-23 17:30:00
# 44792              2023-11-21 06:00:00           2023-11-21 04:30:00
# 20984              2023-06-02 02:00:00           2023-06-01 19:30:00
# 41266              2023-10-26 15:00:00           2023-10-26 12:00:00
# 34352              2023-09-05 21:00:00           2023-09-05 12:20:00
# 35355              2023-09-12 21:00:00           2023-09-12 17:30:00
# 29807              2023-08-02 16:00:00           2023-08-02 12:40:00
# 22530              2023-06-13 19:00:00           2023-06-13 12:45:00
# 37326              2023-09-26 15:00:00           2023-09-26 10:30:00
#
#                  Reference                      Source Service Code  \
# 31990                  NaN                       Phone    EE-MANOUT
# 7071   ST230223.txt - 2138  External Monitoring System     EE-LNOUT
# 44792                  NaN                       Phone    EE-MANOUT
# 20984  ST230601.txt - 4291  External Monitoring System     EE-LNOUT
# 41266                  NaN                       Phone    EE-MANOUT
# 34352                  NaN                       Phone    EE-MANOUT
# 35355                  NaN                       Phone    EE-MANOUT
# 29807                  NaN                       Phone    EE-MANOUT
# 22530                  NaN                       Phone    EE-MANOUT
# 37326                  NaN                       Phone    EE-MANOUT
#
#              Date Created Status Code  \
# 31990 2023-08-18 00:13:00          CL
# 7071  2023-02-23 13:27:00          CL
# 44792 2023-11-21 00:12:00          CL
# 20984 2023-06-01 17:18:00          CL
# 41266 2023-10-26 07:37:00          CL
# 34352 2023-09-05 12:11:00          CL
# 35355 2023-09-12 12:57:00          CL
# 29807 2023-08-02 07:57:00          CL
# 22530 2023-06-13 10:18:00          CL
# 37326 2023-09-26 08:45:00          CL
#
#                                                                                                                                                                                                                                                                                       Outage Comments  \
# 31990  ***This elevator is out of service for ASME CAT 1 Inspection***\nWO6596758   EAM OUT908770\n8/18/23 0013hrs {Jackson,R}E&EM's Daly and Walsh taking unit OOS for CAT 1 Inspection with Third party Inspector Camacho on site EL740 passed cat 1 inspection.   Returned to service at 04:15 am
# 7071                                                                                                                                                                                                                                                                                              NaN
# 44792                                                                                                                      E&EM Furmanov and E&EH Xie Liang did successfully Monthly maintenance El741 . PM completed . BIS at 04:30 E&EM Furmanov and E&EH Xie Liang arrived at 2330 for Monthly PM
# 20984                                                                                                                                                                                                                                                                                             NaN
# 41266                                                                                                                                                                                                                                                                                             NaN
# 34352                                                                                                                                                                                                                                                                                             NaN
# 35355                                                                                                                                                                                                                                                                                             NaN
# 29807                                                 ***This elevator is out of service for preventive maintenance***\n\n\n\nE&EM Samuel & E&EH Shiva arrived at 0715hrs. and taking unit OOS @07:55hrs. for monthly PM.  WO#7501791. E&EM Samuel & E&EH Shiva completed monthly PM. RTS @12:40hrs.
# 22530        ***This elevator is out of service for CAT1 Inspection*** \n\n\nE&EM Stewart, E&EM Rosario, and E&EH Tenecela arrived at 1010hrs. Here for CAT 1 inspection. OOS@1015hrs. wo#6121520 E&EM Stewart, E&EM Rosario, and E&EH Tenecela completed and passed CAT 1 inspection. BIS @1245hrs.
# 37326                                                                                                                                                                                                                                                                                             NaN
#
#       Station MRN
# 31990         NaN
# 7071          NaN
# 44792         NaN
# 20984         NaN
# 41266         NaN
# 34352         NaN
# 35355         NaN
# 29807         NaN
# 22530         NaN
# 37326         NaN

# %%
# geocoding my dataset: merging stations by `Station ID` and `Station MRN` (my dataset)

# convert string to float
df_ele['Station MRN'] = df_ele['Station MRN'].astype('Int64')

# stations with MRN > 523 are not regular subway stations and not geolocatable
# drop all stations MRN > 523 and save to a new file
df_ele[df_ele['Station MRN'] <= 523].to_csv('processed_data/2023_ele.csv', index=False)
df_ele[df_ele['Station MRN'] > 523].to_csv('missing_data/2023_ele_not_subway.csv', index=False)

# filter down to geolocatable columns
df_ele = df_ele[df_ele['Station MRN'] <= 523]
df_ele.sample(5)
# Out:
#       Out of Service Date Common Name  Outage  \
# 42631 2023-11-05 17:23:00       EL502  940020
# 36072 2023-09-16 20:26:00       EL429  920484
# 41928 2023-10-31 23:00:00       EL719  938016
# 31100 2023-08-11 09:06:00       EL219  906233
# 38299 2023-10-03 16:11:00       EL227  927835
#
#                                                Equipment Description  \
# 42631  ELE: EL502 - 211 - Bedford Pk Blvd - Manhattan Bound Platform
# 36072         ELE: EL429 - 273 - Queens Plaza - Manhattan Bound Plat
# 41928                      ELE: EL719 - 106 - Fulton St - Upper Plat
# 31100          ELE: EL219 - 015 - 14 St-Union Sq - Queens Bound Plat
# 38299            ELE: EL227 - 164 - 34 St-Penn Station - Island Plat
#
#                                                      Executive Comment  \
# 42631    This Elevator is out of service due to LIFTNET event: Trouble
# 36072  This Elevator is out service reported by S/A Ahmed pass# 005768
# 41928                   This Elevator is out of service for Inspection
# 31100                                                              NaN
# 38299                                                              NaN
#
#       Outage Code     Status External Source Note Reason Shown to Public  \
# 42631         VAN     Closed              Trouble                 REPAIR
# 36072         VAN     Closed                  NaN           UNDERINVESTG
# 41928         INS     Closed                  NaN             INSPECTION
# 31100         EUF     Closed                  NaN                 REPAIR
# 38299          FR  Cancelled          Stop Switch           UNDERINVESTG
#
#       Reason Shown to Public Description Estimated Return to Service Date  \
# 42631                             Repair              2023-11-06 02:00:00
# 36072                Under Investigation              2023-09-17 08:00:00
# 41928                         Inspection              2023-11-01 07:00:00
# 31100                             Repair              2023-08-12 18:00:00
# 38299                Under Investigation              2023-10-04 01:00:00
#
#       Actual Return to Service Date            Reference  \
# 42631           2023-11-05 20:15:00  ST231105.txt - 1987
# 36072           2023-09-16 21:00:00                  NaN
# 41928           2023-11-01 05:00:00                  NaN
# 31100           2023-08-11 19:00:00                  NaN
# 38299                           NaT  ST231003.txt - 3533
#
#                            Source Service Code        Date Created  \
# 42631  External Monitoring System     EE-LNOUT 2023-11-05 17:36:00
# 36072                       Phone    EE-MANOUT 2023-09-16 20:26:00
# 41928                       Phone    EE-MANOUT 2023-10-31 23:09:00
# 31100                       Phone    EE-MANOUT 2023-08-11 09:18:00
# 38299  External Monitoring System     EE-LNOUT 2023-10-03 16:29:00
#
#       Status Code  \
# 42631          CL
# 36072          CL
# 41928          CL
# 31100          CL
# 38299           C
#
#                                                                                                                                                                                                                         Outage Comments  \
# 42631                                                                                                                                                                                                                               NaN
# 36072                                                                                                                                                                                                                               NaN
# 41928  EEM Daly and EEM Hill arrived at el719 at (22:50) and are removing from service el719 at (23:00) for cat 1 and cat 5 inspection.   WO #7751735 El719 passed cat 1 and cat 5 inspection. Returned el719 back to service at 05:00
# 31100                                                                                                                                                                                                                               NaN
# 38299                                                                                                                                                                                              As per MS1 Lin, machine is running.
#
#        Station MRN
# 42631          211
# 36072          273
# 41928          106
# 31100           15
# 38299          164

# %%
# load the geostation file
df_geostation = pd.read_csv('raw_data/subway_stations.csv')

# merge the geostation file with the df_ele
df_ele_merged = df_ele.merge(df_geostation, left_on='Station MRN', right_on='Station ID')

pd.set_option('display.max_columns', 500)

# rename the columns
df_ele_merged = df_ele_merged.rename(columns={'GTFS Latitude': 'lat',  'GTFS Longitude': 'long'})

# %%
# check the merged file 

# save the merged file
df_ele_merged.to_csv('processed_data/2023_ele_geocode.csv', index=False)
print(df_ele_merged.shape)
df_ele_merged.sample(5)


# WHY IS THERE MORE ROWS THAN THE ORIGINAL FILE??
# Out:
# (18208, 35)
#       Out of Service Date Common Name  Outage  \
# 14444 2023-10-17 12:23:00       EL719  932994
# 1174  2023-01-24 03:39:00       EL441  800456
# 3192  2023-03-07 23:41:00       EL601  817144
# 9640  2023-07-10 09:50:00       EL341  893159
# 7102  2023-05-23 16:47:00       EL127  874540
#
#                                 Equipment Description  \
# 14444       ELE: EL719 - 106 - Fulton St - Upper Plat
# 1174            ELE: EL441 - 223 - Lexington Av/63 St
# 3192   ELE: EL601 - 471 - 34 St-Hudson Yards - Mezz A
# 9640      ELE: EL341 - 188 - Euclid Av - Outside Area
# 7102                    ELE: EL127 - 430 - Simpson St
#
#                                               Executive Comment Outage Code  \
# 14444  This Elevator is out service reported by Vasquez, Edward         BRP
# 1174                                                        NaN         UNI
# 3192                                                        NaN          AP
# 9640                                                        NaN          AP
# 7102                                                        NaN         VAN
#
#           Status  External Source Note Reason Shown to Public  \
# 14444     Closed                   NaN                 REPAIR
# 1174   Cancelled          Fire Phase 1           UNDERINVESTG
# 3192      Closed                   NaN            PLANNEDWORK
# 9640      Closed                   NaN            PLANNEDWORK
# 7102      Closed  Main Line Disconnect           UNDERINVESTG
#
#       Reason Shown to Public Description Estimated Return to Service Date  \
# 14444                             Repair              2023-10-17 21:00:00
# 1174                 Under Investigation              2023-01-24 12:00:00
# 3192                        Planned Work              2023-03-08 08:00:00
# 9640                        Planned Work              2023-07-10 18:00:00
# 7102                 Under Investigation              2023-05-24 01:00:00
#
#       Actual Return to Service Date            Reference  \
# 14444           2023-10-17 13:15:00                  NaN
# 1174                            NaT   ST230124.txt - 778
# 3192            2023-03-08 00:00:00                  NaN
# 9640            2023-07-10 10:15:00                  NaN
# 7102            2023-05-23 19:10:00  ST230523.txt - 3200
#
#                            Source Service Code        Date Created  \
# 14444                       Phone    EE-MANOUT 2023-10-17 12:26:00
# 1174   External Monitoring System     EE-LNOUT 2023-01-24 03:51:00
# 3192                        Phone    EE-MANOUT 2023-03-07 23:42:00
# 9640                        Phone    EE-MANOUT 2023-07-10 09:52:00
# 7102   External Monitoring System     EE-LNOUT 2023-05-23 16:56:00
#
#       Status Code  \
# 14444          CL
# 1174            C
# 3192           CL
# 9640           CL
# 7102           CL
#
#                                                                                                                                                                                                                                                                      Outage Comments  \
# 14444                                                                                                                                                                                                                                                                            NaN
# 1174                                                                                                                                                                                                                         Machine was on fire service due to entrapment on EL442
# 3192                                ***This elevator is out of service for Acces & Protection for Safety***\nEAM OUT817144\n3/07/23 2341hrs {Jackson,R}E&EM Dean and E&EH Ahmed taking unit OOS for A&P for Safety while working on el602 finish fireman service unit BIS @ 0000hrs
# 9640   ***This Escalator is out for A&P for EMD Inspection***\n\n\n07/10/23 E&EM Liu47 arrived@0830hrs. A&P for EMD.\n\nE&EM Rodriguez arrived at EL341. Here to provide A&P for EMD\n\nWO#6548153 E&EM Rodriguez report:  EMD repaired 1 smoke detector in the pit. RTS @10:15hrs.
# 7102                                                                                                                                                                                                                                                                             NaN
#
#        Station MRN  Station ID  Complex ID GTFS Stop ID Division  \
# 14444          106         106         628          M22      BMT
# 1174           223         223         223          B08      IND
# 3192           471         471         471          726      IRT
# 9640           188         188         188          A55      IND
# 7102           430         430         430          217      IRT
#
#                           Line           Stop Name Borough Daytime Routes  \
# 14444                  Jamaica           Fulton St       M            J Z
# 1174                   63rd St  Lexington Av/63 St       M            F Q
# 3192                  Flushing  34 St-Hudson Yards       M              7
# 9640        8th Av - Fulton St           Euclid Av      Bk            A C
# 7102   Lenox - White Plains Rd          Simpson St      Bx            2 5
#
#       Structure        lat       long    North Direction Label  \
# 14444    Subway  40.710374 -74.007582                 Brooklyn
# 1174     Subway  40.764629 -73.966113          Uptown - Queens
# 3192     Subway  40.755882 -74.001910                   Queens
# 9640     Subway  40.675377 -73.872106                Manhattan
# 7102   Elevated  40.824073 -73.893064  Wakefield - Eastchester
#
#       South Direction Label  ADA ADA Notes                  Georeference
# 14444              Broad St    1       NaN  POINT (-74.007582 40.710374)
# 1174    Downtown & Brooklyn    1       NaN  POINT (-73.966113 40.764629)
# 3192                    NaN    1       NaN   POINT (-74.00191 40.755882)
# 9640   Lefferts - Rockaways    1       NaN  POINT (-73.872106 40.675377)
# 7102              Manhattan    1       NaN  POINT (-73.893064 40.824073)

# %% [markdown]
# ## 👉 convert lat/long to census geography codes
#
# (like 'GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK', etc...)
#
# Same note as above, see [census-examples](https://github.com/data4news/census-examples) repository for examples or ask in the class slack channel if stuck.

# %%
import censusgeocode as cg
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm

import requests_cache
cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

def geocode(lat, lng):
    try:
        url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
        params = {
            "x": lng,
            "y": lat,
            "benchmark": "Public_AR_Census2020",
            "vintage": "Census2020_Census2020",
            "format": "json"
        }
        response = cache.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        census = data['result']['geographies']['Census Blocks'][0]
        return census
    except Exception as e:
        print(f"Error geocoding ({lat}, {lng}): {e}")
        return None

def bulk_geocode(latitudes, longitudes):
    """
    Geocode a list of latitudes and longitudes in parallel (for speed).
    """

    with ThreadPoolExecutor() as tpe:
        latitudes = df_ele_merged['lat']
        longitudes = df_ele_merged['long']
        mapped_results = tpe.map(geocode, latitudes, longitudes)
        data = list(tqdm(mapped_results, total=len(df_ele_merged)))

    return pd.DataFrame(data)

census_geos_df = bulk_geocode(df_ele_merged['lat'], df_ele_merged['long']) 
census_geos_df.head()
# Out:
#   0%|          | 0/18208 [00:00<?, ?it/s]
#   SUFFIX  POP100            GEOID      CENTLAT BLOCK  AREAWATER STATE  \
# 0            610  360470296002002  +40.6008553  2002          0    36
# 1              0  360050403021003  +40.8669415  1003          0    36
# 2            593  360610034004000  +40.7305461  4000          0    36
# 3              0  360810208001000  +40.6998869  1000          0    36
# 4              0  360810033011019  +40.7492525  1019          0    36
#
#   BASENAME              OID LSADC     INTPTLAT FUNCSTAT        NAME  OBJECTID  \
# 0     2002  210701004650915    BK  +40.6008553        S  Block 2002   4615836
# 1     1003  210701006017414    BK  +40.8669415        S  Block 1003   1475683
# 2     4000  210701008621623    BK  +40.7305461        S  Block 4000   2844262
# 3     1000  210701006104178    BK  +40.6998869        S  Block 1000   1848413
# 4     1019  210701006117049    BK  +40.7492525        S  Block 1019   1404062
#
#     TRACT       CENTLON BLKGRP  AREALAND  HU100      INTPTLON  MTFCC LWBLKTYP  \
# 0  029600  -073.9943207      2     20213    242  -073.9943207  G5040        L
# 1  040302  -073.8935996      1      3799      0  -073.8935996  G5040        L
# 2  003400  -073.9817046      4     19330    415  -073.9817046  G5040        L
# 3  020800  -073.8089158      1     13876      0  -073.8089158  G5040        L
# 4  003301  -073.9374018      1      3969      0  -073.9374018  G5040        L
#
#   UR COUNTY
# 0  U    047
# 1  U    005
# 2  U    061
# 3  U    081
# 4  U    081

# %%
to_keep = ['GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK']
census_geos_df = census_geos_df[to_keep]
census_geos_df
# Out:
#                  GEOID STATE COUNTY   TRACT BLOCK
# 0      360470296002002    36    047  029600  2002
# 1      360050403021003    36    005  040302  1003
# 2      360610034004000    36    061  003400  4000
# 3      360810208001000    36    081  020800  1000
# 4      360810033011019    36    081  003301  1019
# ...                ...   ...    ...     ...   ...
# 18203  360610137003000    36    061  013700  3000
# 18204  360610137003000    36    061  013700  3000
# 18205  360610137003000    36    061  013700  3000
# 18206  360050224031001    36    005  022403  1001
# 18207  360810216021008    36    081  021602  1008
#
# [18208 rows x 5 columns]

# %% [markdown]
# ## 👉 Output Data
#
# Output your dataframe containing your data and the Census connector codes (like tract, block, etc...).

# %%
df_with_geos = pd.concat(
    [ 
        df_ele_merged.reset_index(drop=True),
        census_geos_df.reset_index(drop=True)
    ], 
    axis=1)

df_with_geos.head()
# Out:
#   Out of Service Date Common Name  Outage  \
# 0 2023-01-01 00:14:00       EL376  791238
# 1 2023-01-01 01:04:00       EL189  791257
# 2 2023-01-01 02:01:00       EL293  791274
# 3 2023-01-01 02:08:00      EL449X  791275
# 4 2023-01-01 05:43:00       EL428  791299
#
#                                Equipment Description Executive Comment  \
# 0         ELE: EL376 - 068 - Bay Pkwy - Outside Area               NaN
# 1   ELE: EL189 - 212 - Kingsbridge Rd - Outside Area               NaN
# 2  ELE: EL293 - 119 - 1 Av - Brooklyn Bound Platform               NaN
# 3  ELE: EL449X - 279 - Sutphin Blvd-Archer Av - Mezz               NaN
# 4     ELE: EL428 - 273 - Queens Plaza - Outside Area               NaN
#
#   Outage Code  Status External Source Note Reason Shown to Public  \
# 0          PM  Closed                  NaN            MAINTENANCE
# 1          AP  Closed                  NaN            PLANNEDWORK
# 2         EUF  Closed  UPS Battery Failure                 REPAIR
# 3         TPE  Closed                  NaN                 REPAIR
# 4         VAN  Closed                  NaN                 REPAIR
#
#   Reason Shown to Public Description Estimated Return to Service Date  \
# 0                        Maintenance              2023-01-01 07:00:00
# 1                       Planned Work              2023-01-01 09:00:00
# 2                             Repair              2023-01-01 11:00:00
# 3                             Repair              2023-01-05 14:00:00
# 4                             Repair              2023-01-01 13:00:00
#
#   Actual Return to Service Date           Reference  \
# 0           2023-01-01 05:30:00                 NaN
# 1           2023-01-01 01:18:00                 NaN
# 2           2023-01-01 04:50:00  ST230101.txt - 192
# 3           2023-01-05 03:06:00                 NaN
# 4           2023-01-01 09:10:00                 NaN
#
#                        Source Service Code        Date Created Status Code  \
# 0                       Phone    EE-MANOUT 2023-01-01 00:14:00          CL
# 1                       Phone    EE-MANOUT 2023-01-01 01:05:00          CL
# 2  External Monitoring System     EE-LNOUT 2023-01-01 02:08:00          CL
# 3                       Phone    EE-MANOUT 2023-01-01 02:09:00          CL
# 4                       Phone    EE-MANOUT 2023-01-01 05:44:00          CL
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Outage Comments  \
# 0                                                                                                                                                                                                                                                                                                                                                                                              ***This Elevator is out of service for Maintenance***\n\n\nE&EM R.Brown and E&Eh K.Singh arrived for maintenance at 00:05. WO #5407916 PM Completed and RTS @5.30
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \n\n***This elevator is out of service for Access & Protection for Safety***
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 3  ***This elevator is out of service as reported by SS Patel010647***\n**This machine is out of service for required repairs. NYC Transit is not responsible for the maintenance or repair of this unit**\n At 22:45 on 01/02/2023 MOW#85 states customers entrapped in EL449x at Sutphin blvd. No medical requested. Notified MS1 Pukhalski   MS1 Pukhalskiy updated by email Checked the EL449X, nobody inside. Sent email to Dist. Field Office for an update. ERTS changed to 01/05/23.\n\n\n S/S Patel reports found machine running while on station. RTS
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
#
#    Station MRN  Station ID  Complex ID GTFS Stop ID Division             Line  \
# 0           68          68          68          B21      BMT         West End
# 1          212         212         212          D04      IND        Concourse
# 2          119         119         119          L06      BMT         Canarsie
# 3          279         279         279          G06      IND  Queens - Archer
# 4          273         273         273          G21      IND      Queens Blvd
#
#                             Stop Name Borough Daytime Routes Structure  \
# 0                            Bay Pkwy      Bk              D  Elevated
# 1                      Kingsbridge Rd      Bx            B D    Subway
# 2                                1 Av       M              L    Subway
# 3  Sutphin Blvd-Archer Av-JFK Airport       Q          E J Z    Subway
# 4                        Queens Plaza       Q          E M R    Subway
#
#          lat       long     North Direction Label South Direction Label  ADA  \
# 0  40.601875 -73.993728                 Manhattan          Coney Island    1
# 1  40.866978 -73.893509  Bedford Pk Blvd & 205 St             Manhattan    1
# 2  40.730953 -73.981628                      8 Av              Brooklyn    1
# 3  40.700486 -73.807969            Jamaica Center             Manhattan    1
# 4  40.748973 -73.937243    Forest Hills - Jamaica             Manhattan    1
#
#   ADA Notes                  Georeference            GEOID STATE COUNTY  \
# 0       NaN  POINT (-73.993728 40.601875)  360470296002002    36    047
# 1       NaN  POINT (-73.893509 40.866978)  360050403021003    36    005
# 2       NaN  POINT (-73.981628 40.730953)  360610034004000    36    061
# 3       NaN  POINT (-73.807969 40.700486)  360810208001000    36    081
# 4       NaN  POINT (-73.937243 40.748973)  360810033011019    36    081
#
#     TRACT BLOCK
# 0  029600  2002
# 1  040302  1003
# 2  003400  4000
# 3  020800  1000
# 4  003301  1019

# %%
df_with_geos.to_csv('data/2023_subway_censusgeo.csv', index=False)
